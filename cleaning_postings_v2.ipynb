# %% [markdown]
# The postings table has data that requires flattening. Some members switched parties and these changes need to be considered a separate posting for the durations served with each party.

# %%
# Import Dependencies
import pandas as pd
from datetime import datetime
import csv
import re

# %%
# Load the postings CSV file into a DataFrame
postings_df = pd.read_csv('data\\postings.csv', dtype=str)
postings_df.head()
# Out:
#   bioguide_id         chamber           job_type congress_number  \
# 0     A000002  Representative  CongressMemberJob              86
# 1     A000016  Representative  CongressMemberJob              86
# 2     A000024  Representative  CongressMemberJob              86
# 3     A000054  Representative  CongressMemberJob              86
# 4     A000062         Senator  CongressMemberJob              86
#
#   congress_start_date congress_end_date  region_type region_code  party_name  \
# 0          1959-01-03        1961-01-03  StateRegion          VA    Democrat
# 1          1959-01-03        1961-01-03  StateRegion          MS    Democrat
# 2          1959-01-03        1961-01-03  StateRegion          IN  Republican
# 3          1959-01-03        1961-01-03  StateRegion          NJ    Democrat
# 4          1959-01-03        1961-01-03  StateRegion          VT  Republican
#
#   job_start_date job_end_date party_start_date party_end_date
# 0            NaN          NaN              NaN            NaN
# 1            NaN          NaN              NaN            NaN
# 2            NaN          NaN              NaN            NaN
# 3            NaN          NaN              NaN            NaN
# 4            NaN          NaN              NaN            NaN

# %%
postings_df.shape
# Out:
# (36714, 13)

# %%
# Remove duplicate rows from postings_df
# Check for duplicate rows
duplicates_before = postings_df[postings_df.duplicated()]
print(f"Number of duplicate rows before cleaning: {len(duplicates_before)}")
# Remove duplicates
postings_df = postings_df.drop_duplicates()
print(f"Number of rows after removing duplicates: {len(postings_df)}")
postings_df.shape
# Out:
# Number of duplicate rows before cleaning: 18357
# Number of rows after removing duplicates: 18357
# (18357, 13)

# %% [markdown]
# 18 members had switched parties while in office. A new extraction logic needed to be used to expand each posting into separate ones with a single party.

# %%
# Make a list of bioguide_ids where the party_name column contains a list containing more than one party
# This confirms that the new extraction logic is working as intended
# Ignore NaN values
multi_party_bioguide_ids = postings_df[postings_df['party_name'].str.contains(',', na=False)]['bioguide_id'].unique().tolist()
# print the list
print(multi_party_bioguide_ids)
# print a count of how many bioguide_ids are in the list
print(f"Number of bioguide_ids with multiple parties: {len(multi_party_bioguide_ids)}")
# Out:
# []
# Number of bioguide_ids with multiple parties: 0

# %% [markdown]
# A data error was found during exploration. The start date of the first congress served would be found in the start date of the final term served.

# %%
# Convert date columns to datetime format
date_columns = ['job_start_date', 'job_end_date', 'congress_start_date', 'congress_end_date', 'party_start_date', 'party_end_date']
for col in date_columns:
    postings_df[col] = pd.to_datetime(postings_df[col], errors='coerce')
# Verify dtype conversion
postings_df.dtypes
# Out:
# bioguide_id                    object
# chamber                        object
# job_type                       object
# congress_number                object
# congress_start_date    datetime64[ns]
# congress_end_date      datetime64[ns]
# region_type                    object
# region_code                    object
# party_name                     object
# job_start_date         datetime64[ns]
# job_end_date           datetime64[ns]
# party_start_date       datetime64[ns]
# party_end_date         datetime64[ns]
# dtype: object

# %%
# Make a list of bioguide_ids where the job_start_date is earlier than the congress_start_date
date_error_bioguide_ids_after = postings_df[pd.to_datetime(postings_df['job_start_date'], errors='coerce') < pd.to_datetime(postings_df['congress_start_date'], errors='coerce')]['bioguide_id'].unique().tolist()
print(date_error_bioguide_ids_after)
# print a count of how many bioguide_ids are in the list
print(f"Number of bioguide_ids with job_start_date earlier than congress_start_date after cleaning: {len(date_error_bioguide_ids_after)}")
# Out:
# ['B000223', 'P000152', 'B001251', 'B001270', 'D000482', 'G000582', 'M001165']
# Number of bioguide_ids with job_start_date earlier than congress_start_date after cleaning: 7

# %%
# Show all the rows for the date_error_bioguide_ids_after list
date_error_df_after = postings_df[postings_df['bioguide_id'].isin(date_error_bioguide_ids_after)]
date_error_df_after.head(20)
# Out:
#       bioguide_id         chamber           job_type congress_number  \
# 34        B000223  Representative  CongressMemberJob              86
# 1153      B000223  Representative  CongressMemberJob              87
# 2283      B000223         Senator  CongressMemberJob              88
# 2284      B000223  Representative  CongressMemberJob              88
# 3400      B000223         Senator  CongressMemberJob              89
# 15972     P000152  Representative  CongressMemberJob             100
# 17080     P000152  Representative  CongressMemberJob             101
# 18201     P000152  Representative  CongressMemberJob             102
# 19323     P000152  Representative  CongressMemberJob             103
# 20176     D000482  Representative  CongressMemberJob             104
# 20437     P000152  Representative  CongressMemberJob             104
# 21280     D000482  Representative  CongressMemberJob             105
# 22383     D000482  Representative  CongressMemberJob             106
# 23479     D000482  Representative  CongressMemberJob             107
# 24525     B001251  Representative  CongressMemberJob             108
# 24598     D000482  Representative  CongressMemberJob             108
# 25614     B001251  Representative  CongressMemberJob             109
# 25690     D000482  Representative  CongressMemberJob             109
# 26704     B001251  Representative  CongressMemberJob             110
# 26788     D000482  Representative  CongressMemberJob             110
#
#       congress_start_date congress_end_date  region_type region_code  \
# 34             1959-01-03        1961-01-03  StateRegion          TN
# 1153           1961-01-03        1963-01-03  StateRegion          TN
# 2283           1963-01-03        1965-01-03  StateRegion          TN
# 2284           1963-01-03        1965-01-03  StateRegion          TN
# 3400           1965-01-03        1967-01-03  StateRegion          TN
# 15972          1987-01-03        1989-01-03  StateRegion          VA
# 17080          1989-01-03        1991-01-03  StateRegion          VA
# 18201          1991-01-03        1993-01-03  StateRegion          VA
# 19323          1993-01-03        1995-01-03  StateRegion          VA
# 20176          1995-01-03        1997-01-03  StateRegion          PA
# 20437          1995-01-03        1997-01-03  StateRegion          VA
# 21280          1997-01-03        1999-01-03  StateRegion          PA
# 22383          1999-01-03        2001-01-03  StateRegion          PA
# 23479          2001-01-03        2003-01-03  StateRegion          PA
# 24525          2003-01-03        2005-01-03  StateRegion          NC
# 24598          2003-01-03        2005-01-03  StateRegion          PA
# 25614          2005-01-03        2007-01-03  StateRegion          NC
# 25690          2005-01-03        2007-01-03  StateRegion          PA
# 26704          2007-01-03        2009-01-03  StateRegion          NC
# 26788          2007-01-03        2009-01-03  StateRegion          PA
#
#       party_name job_start_date job_end_date party_start_date party_end_date
# 34      Democrat            NaT          NaT              NaT            NaT
# 1153    Democrat            NaT          NaT              NaT            NaT
# 2283    Democrat     1964-11-04          NaT              NaT            NaT
# 2284         NaN     1953-01-03   1964-11-03              NaT            NaT
# 3400    Democrat            NaT   1967-01-03              NaT            NaT
# 15972   Democrat            NaT          NaT              NaT            NaT
# 17080   Democrat            NaT          NaT              NaT            NaT
# 18201   Democrat            NaT          NaT              NaT            NaT
# 19323   Democrat            NaT          NaT              NaT            NaT
# 20176   Democrat            NaT          NaT              NaT            NaT
# 20437   Democrat     1988-06-14          NaT              NaT            NaT
# 21280   Democrat            NaT          NaT              NaT            NaT
# 22383   Democrat            NaT          NaT              NaT            NaT
# 23479   Democrat            NaT          NaT              NaT            NaT
# 24525   Democrat            NaT          NaT              NaT            NaT
# 24598   Democrat            NaT          NaT              NaT            NaT
# 25614   Democrat            NaT          NaT              NaT            NaT
# 25690   Democrat            NaT          NaT              NaT            NaT
# 26704   Democrat            NaT          NaT              NaT            NaT
# 26788   Democrat            NaT          NaT              NaT            NaT

# %%
# if job_start_date or job_end_date is on a January third, delete that datapoint
# Count the number of values that are January 3rd before deleting
jan_3_start_count = len(postings_df[postings_df['job_start_date'].str.endswith('-01-03', na=False)])
jan_3_end_count = len(postings_df[postings_df['job_end_date'].str.endswith('-01-03', na=False)])
print(f"Number of job_start_date values on January 3rd: {jan_3_start_count}")
print(f"Number of job_end_date values on January 3rd: {jan_3_end_count}")
# Clear those values
postings_df.loc[postings_df['job_start_date'].str.endswith('-01-03', na=False), 'job_start_date'] = None
postings_df.loc[postings_df['job_end_date'].str.endswith('-01-03', na=False), 'job_end_date'] = None
# Count the number of values that are January 3rd after deleting
jan_3_start_count_after = len(postings_df[postings_df['job_start_date'].str.endswith('-01-03', na=False)])
jan_3_end_count_after = len(postings_df[postings_df['job_end_date'].str.endswith('-01-03', na=False)])
print(f"Number of job_start_date values on January 3rd after deletion: {jan_3_start_count_after}")
print(f"Number of job_end_date values on January 3rd after deletion: {jan_3_end_count_after}")
# Out:
# Number of job_start_date values on January 3rd: 1010
# Number of job_end_date values on January 3rd: 574
# Number of job_start_date values on January 3rd after deletion: 0
# Number of job_end_date values on January 3rd after deletion: 0

# %%
# remove duplicate rows again to ensure none were reintroduced
duplicates_after = postings_df[postings_df.duplicated()]
print(f"Number of duplicate rows after cleaning: {len(duplicates_after)}")
# Save the cleaned DataFrame back to a CSV file
postings_df.to_csv('data\\postings_working.csv', index=False, quoting=csv.QUOTE_NONNUMERIC)
# Out:
# Number of duplicate rows after cleaning: 18357

# %%
# count the number of duplicate rows again
duplicates_after = postings_df[postings_df.duplicated()]
print(f"Number of duplicate rows before dropping: {len(duplicates_after)}")
# drop duplicate rows again
postings_df = postings_df.drop_duplicates()
# count the number of duplicate after dropping
duplicates_after = postings_df[postings_df.duplicated()]
print(f"Number of duplicate rows after dropping: {len(duplicates_after)}")
postings_df.shape
# Out:
# Number of duplicate rows before dropping: 0
# Number of duplicate rows after dropping: 0
# (18357, 13)

# %%
# Check for any rows where job_start_date is earlier than congress_start_date again
date_error_bioguide_ids_after = postings_df[pd.to_datetime(postings_df['job_start_date'], errors='coerce') < pd.to_datetime(postings_df['congress_start_date'], errors='coerce')]['bioguide_id'].unique().tolist()
print(date_error_bioguide_ids_after)
# print a count of how many bioguide_ids are in the list
print(f"Number of bioguide_ids with job_start_date earlier than congress_start_date after cleaning: {len(date_error_bioguide_ids_after)}")
# Out:
# ['P000152', 'B001251']
# Number of bioguide_ids with job_start_date earlier than congress_start_date after cleaning: 2

# %%
# Show all the rows with the date_error_bioguide_ids_after
date_error_df_after = postings_df[postings_df['bioguide_id'].isin(date_error_bioguide_ids_after)]
date_error_df_after.head(20)
# Out:
#       bioguide_id         chamber           job_type congress_number  \
# 15972     P000152  Representative  CongressMemberJob             100
# 17080     P000152  Representative  CongressMemberJob             101
# 18201     P000152  Representative  CongressMemberJob             102
# 19323     P000152  Representative  CongressMemberJob             103
# 20437     P000152  Representative  CongressMemberJob             104
# 24525     B001251  Representative  CongressMemberJob             108
# 25614     B001251  Representative  CongressMemberJob             109
# 26704     B001251  Representative  CongressMemberJob             110
# 27818     B001251  Representative  CongressMemberJob             111
# 28938     B001251  Representative  CongressMemberJob             112
# 30036     B001251  Representative  CongressMemberJob             113
# 31150     B001251  Representative  CongressMemberJob             114
# 32247     B001251  Representative  CongressMemberJob             115
# 33377     B001251  Representative  CongressMemberJob             116
# 34492     B001251  Representative  CongressMemberJob             117
#
#       congress_start_date congress_end_date     region_type region_code  \
# 15972          1987-01-03        1989-01-03     StateRegion          VA
# 17080          1989-01-03        1991-01-03     StateRegion          VA
# 18201          1991-01-03        1993-01-03     StateRegion          VA
# 19323          1993-01-03        1995-01-03     StateRegion          VA
# 20437          1995-01-03        1997-01-03     StateRegion          VA
# 24525          2003-01-03        2005-01-03     StateRegion          NC
# 25614          2005-01-03        2007-01-03     StateRegion          NC
# 26704          2007-01-03        2009-01-03     StateRegion          NC
# 27818          2009-01-03        2011-01-03     StateRegion          NC
# 28938          2011-01-03        2013-01-03     StateRegion          NC
# 30036          2013-01-03        2015-01-03     StateRegion          NC
# 31150          2015-01-03        2017-01-03     StateRegion          NC
# 32247          2017-01-03        2019-01-03     StateRegion          NC
# 33377          2019-01-03        2021-01-03     StateRegion          NC
# 34492          2021-01-03        2023-01-03  DistrictRegion          NC
#
#       party_name job_start_date job_end_date party_start_date party_end_date
# 15972   Democrat            NaN          NaN              NaN            NaN
# 17080   Democrat            NaN          NaN              NaN            NaN
# 18201   Democrat            NaN          NaN              NaN            NaN
# 19323   Democrat            NaN          NaN              NaN            NaN
# 20437   Democrat     1988-06-14          NaN              NaN            NaN
# 24525   Democrat            NaN          NaN              NaN            NaN
# 25614   Democrat            NaN          NaN              NaN            NaN
# 26704   Democrat            NaN          NaN              NaN            NaN
# 27818   Democrat            NaN          NaN              NaN            NaN
# 28938   Democrat            NaN          NaN              NaN            NaN
# 30036   Democrat            NaN          NaN              NaN            NaN
# 31150   Democrat            NaN          NaN              NaN            NaN
# 32247   Democrat            NaN          NaN              NaN            NaN
# 33377   Democrat            NaN          NaN              NaN            NaN
# 34492   Democrat     2004-07-20   2022-12-30              NaN            NaN

# %%
#
